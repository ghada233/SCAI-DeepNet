# %% [markdown]
# <a href="https://colab.research.google.com/github/ghada233/SCAI-DeepNet/blob/main/goal_keeper_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install ultralytics numpy opencv-python matplotlib gym torch
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.104-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading ultralytics-8.3.104-py3-none-any.whl (994 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.1/994.1 kB 32.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 18.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 19.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.104 ultralytics-thop-2.0.14

# %%
import cv2
from ultralytics import YOLO
import numpy as np

# Load YOLO model
model = YOLO('yolov8n.pt')  # Using nano version for faster processing

# Process video and print debug info
def process_video_debug(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    detections = []

    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Run YOLO detection
        results = model(frame, verbose=False)  # Disable YOLO output

        # Store frame and detections
        frames.append(frame)
        detections.append(results)

        frame_count += 1
        print(f"Processed frame {frame_count}")

    cap.release()
    print(f"Total frames processed: {len(frames)}")
    print(f"Total detections: {len(detections)}")
    return frames, detections

# Process video
frames, detections = process_video_debug('/content/istockphoto-949472108-640_adpp_is.mp4')
# Out:
# Processed frame 1
# Processed frame 2
# Processed frame 3
# Processed frame 4
# Processed frame 5
# Processed frame 6
# Processed frame 7
# Processed frame 8
# Processed frame 9
# Processed frame 10
# Processed frame 11
# Processed frame 12
# Processed frame 13
# Processed frame 14
# Processed frame 15
# Processed frame 16
# Processed frame 17
# Processed frame 18
# Processed frame 19
# Processed frame 20
# Processed frame 21
# Processed frame 22
# Processed frame 23
# Processed frame 24
# Processed frame 25
# Processed frame 26
# Processed frame 27
# Processed frame 28
# Processed frame 29
# Processed frame 30
# Processed frame 31
# Processed frame 32
# Processed frame 33
# Processed frame 34
# Processed frame 35
# Processed frame 36
# Processed frame 37
# Processed frame 38
# Processed frame 39
# Processed frame 40
# Processed frame 41
# Processed frame 42
# Processed frame 43
# Processed frame 44
# Processed frame 45
# Processed frame 46
# Processed frame 47
# Processed frame 48
# Processed frame 49
# Processed frame 50
# Processed frame 51
# Processed frame 52
# Processed frame 53
# Processed frame 54
# Processed frame 55
# Processed frame 56
# Processed frame 57
# Processed frame 58
# Processed frame 59
# Processed frame 60
# Processed frame 61
# Processed frame 62
# Processed frame 63
# Processed frame 64
# Processed frame 65
# Processed frame 66
# Processed frame 67
# Processed frame 68
# Processed frame 69
# Processed frame 70
# Processed frame 71
# Processed frame 72
# Processed frame 73
# Processed frame 74
# Processed frame 75
# Processed frame 76
# Processed frame 77
# Processed frame 78
# Processed frame 79
# Processed frame 80
# Processed frame 81
# Processed frame 82
# Processed frame 83
# Processed frame 84
# Processed frame 85
# Processed frame 86
# Processed frame 87
# Processed frame 88
# Processed frame 89
# Processed frame 90
# Processed frame 91
# Processed frame 92
# Processed frame 93
# Processed frame 94
# Processed frame 95
# Processed frame 96
# Processed frame 97
# Processed frame 98
# Processed frame 99
# Processed frame 100
# Processed frame 101
# Processed frame 102
# Processed frame 103
# Processed frame 104
# Processed frame 105
# Processed frame 106
# Processed frame 107
# Processed frame 108
# Processed frame 109
# Processed frame 110
# Processed frame 111
# Processed frame 112
# Processed frame 113
# Processed frame 114
# Processed frame 115
# Processed frame 116
# Processed frame 117
# Processed frame 118
# Processed frame 119
# Processed frame 120
# Processed frame 121
# Processed frame 122
# Processed frame 627
# Processed frame 628
# Processed frame 629
# Processed frame 630
# Processed frame 631
# Processed frame 632
# Processed frame 633
# Processed frame 634
# Processed frame 635
# Processed frame 636
# Processed frame 637
# Processed frame 638
# Processed frame 639
# Processed frame 640
# Processed frame 641
# Processed frame 642
# Processed frame 643
# Processed frame 644
# Processed frame 645
# Processed frame 646
# Total frames processed: 646
# Total detections: 646

# %%
def extract_detection_data(detections):
    extracted_data = []

    for det in detections:
        frame_data = {
            'ball': None,
            'kicker': None,
            'goalkeeper': None,
            'goalpost': None
        }

        # Get all detected objects
        for box in det[0].boxes:
            cls = int(box.cls)
            conf = float(box.conf)
            xyxy = box.xyxy[0].tolist()  # [x1, y1, x2, y2]

            # Person (player)
            if cls == 0 and conf > 0.5:
                if frame_data['kicker'] is None:  # First person is kicker
                    frame_data['kicker'] = xyxy
                else:  # Second person is goalkeeper
                    frame_data['goalkeeper'] = xyxy

            # Sports ball
            elif cls == 32 and conf > 0.3:
                frame_data['ball'] = xyxy


        # If no ball detected, use center position as fallback
        if frame_data['ball'] is None:
            frame_data['ball'] = [0.5, 0.5, 0.5, 0.5]

        extracted_data.append(frame_data)

    return extracted_data

detection_data = extract_detection_data(detections)
print(f"Extracted data for {len(detection_data)} frames")
# Out:
# Extracted data for 646 frames

# %%
import gym
from gym import spaces

class PenaltyEnv(gym.Env):
    def __init__(self, detection_data):
        super(PenaltyEnv, self).__init__()
        self.detection_data = detection_data
        self.current_frame = 0

        # Action space: left, center, right
        self.action_space = spaces.Discrete(3)

        # Observation space: ball x position, ball y position, kicker x position
        self.observation_space = spaces.Box(
            low=np.array([0, 0, 0]),
            high=np.array([1, 1, 1]),
            dtype=np.float32
        )

    def _get_obs(self):
        if len(self.detection_data) == 0:
            return np.array([0.5, 0.5, 0.5], dtype=np.float32)

        frame_data = self.detection_data[self.current_frame]

        # Get normalized positions
        ball_x = (frame_data['ball'][0] + frame_data['ball'][2]) / 2  # Average x position
        ball_y = (frame_data['ball'][1] + frame_data['ball'][3]) / 2  # Average y position

        if frame_data['kicker'] is not None:
            kicker_x = (frame_data['kicker'][0] + frame_data['kicker'][2]) / 2
        else:
            kicker_x = 0.5

        return np.array([ball_x, ball_y, kicker_x], dtype=np.float32)

    def step(self, action):
        if len(self.detection_data) == 0:
            return self._get_obs(), 0, True, {}

        # Simple reward logic based on ball position
        ball_x = (self.detection_data[self.current_frame]['ball'][0] +
                 self.detection_data[self.current_frame]['ball'][2]) / 2

        # Determine if action was correct
        if action == 0 and ball_x < 0.33:  # left
            reward = 1
        elif action == 1 and 0.33 <= ball_x <= 0.66:  # center
            reward = 1
        elif action == 2 and ball_x > 0.66:  # right
            reward = 1
        else:
            reward = -1

        self.current_frame += 1
        done = self.current_frame >= len(self.detection_data) - 1

        return self._get_obs(), reward, done, {}

    def reset(self):
        self.current_frame = 0
        return self._get_obs()

# %%
class QLearningAgent:
    def __init__(self, env, learning_rate=0.1, discount_factor=0.9,
                 exploration_rate=1.0, exploration_decay=0.995):
        self.env = env
        self.lr = learning_rate
        self.gamma = discount_factor
        self.epsilon = exploration_rate
        self.epsilon_decay = exploration_decay

        # Create Q-table with appropriate dimensions
        # We'll use 10 bins for each of the 3 state variables
        self.q_table = np.zeros((10, 10, 10, env.action_space.n))  # 10x10x10x3

    def discretize_state(self, state):
        # Convert continuous state to discrete bins (0-9)
        # Clip values to ensure they stay within bounds
        discretized = []
        for value in state:
            # Scale value to 0-9 range and ensure it's an integer
            scaled = int(np.clip(value * 10, 0, 9))
            discretized.append(scaled)
        return tuple(discretized)

    def get_action(self, state):
        if np.random.random() < self.epsilon:
            return self.env.action_space.sample()  # Explore
        discrete_state = self.discretize_state(state)
        return np.argmax(self.q_table[discrete_state])

    def learn(self, state, action, reward, next_state):
        discrete_state = self.discretize_state(state)
        discrete_next_state = self.discretize_state(next_state)

        # Q-learning update
        best_next_action = np.argmax(self.q_table[discrete_next_state])
        td_target = reward + self.gamma * self.q_table[discrete_next_state][best_next_action]
        td_error = td_target - self.q_table[discrete_state][action]
        self.q_table[discrete_state][action] += self.lr * td_error

        # Decay exploration rate
        self.epsilon *= self.epsilon_decay

# %%
# Create environment only if we have detection data
if len(detection_data) > 0:
    env = PenaltyEnv(detection_data)
    agent = QLearningAgent(env)

    # Training loop
    num_episodes = 50  # Reduced for demo purposes
    for episode in range(num_episodes):
        state = env.reset()
        total_reward = 0
        done = False

        while not done:
            action = agent.get_action(state)
            next_state, reward, done, _ = env.step(action)
            agent.learn(state, action, reward, next_state)
            state = next_state
            total_reward += reward

        print(f"Episode {episode + 1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.2f}")

    # Test the agent
    state = env.reset()
    done = False
    while not done:
        action = agent.get_action(state)
        print(f"Frame {env.current_frame}: Suggested action - {'left' if action == 0 else 'center' if action == 1 else 'right'}")
        state, _, done, _ = env.step(action)
else:
    print("No detection data available. Check video processing.")
# Out:
# Episode 1, Total Reward: 407, Epsilon: 0.04
# Episode 2, Total Reward: 635, Epsilon: 0.00
# /usr/local/lib/python3.11/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Episode 3, Total Reward: 645, Epsilon: 0.00
# Episode 4, Total Reward: 645, Epsilon: 0.00
# Episode 5, Total Reward: 645, Epsilon: 0.00
# Episode 6, Total Reward: 645, Epsilon: 0.00
# Episode 7, Total Reward: 645, Epsilon: 0.00
# Episode 8, Total Reward: 645, Epsilon: 0.00
# Episode 9, Total Reward: 645, Epsilon: 0.00
# Episode 10, Total Reward: 645, Epsilon: 0.00
# Episode 11, Total Reward: 645, Epsilon: 0.00
# Episode 12, Total Reward: 645, Epsilon: 0.00
# Episode 13, Total Reward: 645, Epsilon: 0.00
# Episode 14, Total Reward: 645, Epsilon: 0.00
# Episode 15, Total Reward: 645, Epsilon: 0.00
# Episode 16, Total Reward: 645, Epsilon: 0.00
# Episode 17, Total Reward: 645, Epsilon: 0.00
# Episode 18, Total Reward: 645, Epsilon: 0.00
# Episode 19, Total Reward: 645, Epsilon: 0.00
# Episode 20, Total Reward: 645, Epsilon: 0.00
# Episode 21, Total Reward: 645, Epsilon: 0.00
# Episode 22, Total Reward: 645, Epsilon: 0.00
# Episode 23, Total Reward: 645, Epsilon: 0.00
# Episode 24, Total Reward: 645, Epsilon: 0.00
# Episode 25, Total Reward: 645, Epsilon: 0.00
# Episode 26, Total Reward: 645, Epsilon: 0.00
# Episode 27, Total Reward: 645, Epsilon: 0.00
# Episode 28, Total Reward: 645, Epsilon: 0.00
# Episode 29, Total Reward: 645, Epsilon: 0.00
# Episode 30, Total Reward: 645, Epsilon: 0.00
# Episode 31, Total Reward: 645, Epsilon: 0.00
# Episode 32, Total Reward: 645, Epsilon: 0.00
# Episode 33, Total Reward: 645, Epsilon: 0.00
# Episode 34, Total Reward: 645, Epsilon: 0.00
# Episode 35, Total Reward: 645, Epsilon: 0.00
# Episode 36, Total Reward: 645, Epsilon: 0.00
# Episode 37, Total Reward: 645, Epsilon: 0.00
# Episode 38, Total Reward: 645, Epsilon: 0.00
# Episode 39, Total Reward: 645, Epsilon: 0.00
# Episode 40, Total Reward: 645, Epsilon: 0.00
# Episode 41, Total Reward: 645, Epsilon: 0.00
# Episode 42, Total Reward: 645, Epsilon: 0.00
# Episode 43, Total Reward: 645, Epsilon: 0.00
# Episode 44, Total Reward: 645, Epsilon: 0.00
# Episode 45, Total Reward: 645, Epsilon: 0.00
# Episode 46, Total Reward: 645, Epsilon: 0.00
# Episode 47, Total Reward: 645, Epsilon: 0.00
# Episode 48, Total Reward: 645, Epsilon: 0.00
# Episode 49, Total Reward: 645, Epsilon: 0.00
# Episode 50, Total Reward: 645, Epsilon: 0.00
# Frame 0: Suggested action - center
# Frame 1: Suggested action - center
# Frame 2: Suggested action - center
# Frame 3: Suggested action - center
# Frame 4: Suggested action - center
# Frame 5: Suggested action - center
# Frame 6: Suggested action - center
# Frame 7: Suggested action - center
# Frame 8: Suggested action - center
# Frame 9: Suggested action - center
# Frame 10: Suggested action - center
# Frame 11: Suggested action - center
# Frame 12: Suggested action - center
# Frame 13: Suggested action - center
# Frame 14: Suggested action - center
# Frame 15: Suggested action - center
# Frame 16: Suggested action - center
# Frame 17: Suggested action - center
# Frame 18: Suggested action - center
# Frame 19: Suggested action - center
# Frame 20: Suggested action - center
# Frame 21: Suggested action - center
# Frame 22: Suggested action - center
# Frame 23: Suggested action - center
# Frame 24: Suggested action - center
# Frame 25: Suggested action - center
# Frame 26: Suggested action - center
# Frame 27: Suggested action - center
# Frame 28: Suggested action - center
# Frame 29: Suggested action - center
# Frame 30: Suggested action - center
# Frame 31: Suggested action - center
# Frame 32: Suggested action - center
# Frame 33: Suggested action - center
# Frame 34: Suggested action - center
# Frame 35: Suggested action - center
# Frame 36: Suggested action - center
# Frame 37: Suggested action - center
# Frame 38: Suggested action - center
# Frame 39: Suggested action - center
# Frame 40: Suggested action - center
# Frame 41: Suggested action - center
# Frame 42: Suggested action - center
# Frame 43: Suggested action - center
# Frame 44: Suggested action - center
# Frame 45: Suggested action - center
# Frame 46: Suggested action - center
# Frame 47: Suggested action - center
# Frame 48: Suggested action - center
# Frame 49: Suggested action - center
# Frame 50: Suggested action - center
# Frame 51: Suggested action - center
# Frame 52: Suggested action - center
# Frame 53: Suggested action - center
# Frame 54: Suggested action - center
# Frame 55: Suggested action - center
# Frame 56: Suggested action - center
# Frame 57: Suggested action - center
# Frame 58: Suggested action - center
# Frame 59: Suggested action - center
# Frame 60: Suggested action - center
# Frame 61: Suggested action - center
# Frame 62: Suggested action - center
# Frame 63: Suggested action - center
# Frame 64: Suggested action - center
# Frame 65: Suggested action - center
# Frame 66: Suggested action - center
# Frame 67: Suggested action - center
# Frame 68: Suggested action - center
# Frame 69: Suggested action - center
# Frame 70: Suggested action - center
# Frame 71: Suggested action - center
# Frame 72: Suggested action - center
# Frame 73: Suggested action - center
# Frame 74: Suggested action - center
# Frame 75: Suggested action - center
# Frame 76: Suggested action - center
# Frame 77: Suggested action - center
# Frame 78: Suggested action - center
# Frame 79: Suggested action - center
# Frame 80: Suggested action - center
# Frame 81: Suggested action - center
# Frame 82: Suggested action - center
# Frame 83: Suggested action - center
# Frame 84: Suggested action - center
# Frame 85: Suggested action - center
# Frame 86: Suggested action - center
# Frame 87: Suggested action - center
# Frame 88: Suggested action - center
# Frame 89: Suggested action - center
# Frame 90: Suggested action - center
# Frame 91: Suggested action - center
# Frame 92: Suggested action - center
# Frame 93: Suggested action - center
# Frame 94: Suggested action - center
# Frame 95: Suggested action - center
# Frame 96: Suggested action - center
# Frame 97: Suggested action - center
# Frame 98: Suggested action - center
# Frame 99: Suggested action - center
# Frame 100: Suggested action - center
# Frame 101: Suggested action - center
# Frame 102: Suggested action - center
# Frame 103: Suggested action - center
# Frame 104: Suggested action - center
# Frame 105: Suggested action - center
# Frame 106: Suggested action - center
# Frame 107: Suggested action - center
# Frame 108: Suggested action - center
# Frame 109: Suggested action - center
# Frame 110: Suggested action - center
# Frame 111: Suggested action - center
# Frame 112: Suggested action - center
# Frame 113: Suggested action - center
# Frame 114: Suggested action - center
# Frame 115: Suggested action - center
# Frame 116: Suggested action - center
# Frame 117: Suggested action - center
# Frame 118: Suggested action - center
# Frame 119: Suggested action - center
# Frame 120: Suggested action - center
# Frame 121: Suggested action - center
# Frame 122: Suggested action - center
# Frame 123: Suggested action - center
# Frame 124: Suggested action - center
# Frame 125: Suggested action - center
# Frame 126: Suggested action - center
# Frame 127: Suggested action - center
# Frame 128: Suggested action - center
# Frame 129: Suggested action - center
# Frame 130: Suggested action - center
# Frame 131: Suggested action - center
# Frame 132: Suggested action - center
# Frame 133: Suggested action - center
# Frame 134: Suggested action - center
# Frame 135: Suggested action - center
# Frame 136: Suggested action - center
# Frame 137: Suggested action - center
# Frame 138: Suggested action - center
# Frame 139: Suggested action - center
# Frame 140: Suggested action - center
# Frame 141: Suggested action - center
# Frame 142: Suggested action - center
# Frame 143: Suggested action - center
# Frame 144: Suggested action - center
# Frame 145: Suggested action - center
# Frame 146: Suggested action - center
# Frame 147: Suggested action - center
# Frame 148: Suggested action - center
# Frame 149: Suggested action - center
# Frame 150: Suggested action - center
# Frame 151: Suggested action - center
# Frame 152: Suggested action - center
# Frame 153: Suggested action - center
# Frame 154: Suggested action - center
# Frame 155: Suggested action - center
# Frame 156: Suggested action - center
# Frame 157: Suggested action - center
# Frame 158: Suggested action - center
# Frame 159: Suggested action - center
# Frame 160: Suggested action - center
# Frame 161: Suggested action - right
# Frame 162: Suggested action - right
# Frame 163: Suggested action - right
# Frame 164: Suggested action - right
# Frame 165: Suggested action - right
# Frame 166: Suggested action - right
# Frame 167: Suggested action - right
# Frame 168: Suggested action - right
# Frame 169: Suggested action - right
# Frame 170: Suggested action - right
# Frame 171: Suggested action - right
# Frame 172: Suggested action - right
# Frame 173: Suggested action - right
# Frame 174: Suggested action - right
# Frame 175: Suggested action - right
# Frame 176: Suggested action - right
# Frame 177: Suggested action - right
# Frame 178: Suggested action - right
# Frame 179: Suggested action - right
# Frame 180: Suggested action - right
# Frame 181: Suggested action - right
# Frame 182: Suggested action - right
# Frame 183: Suggested action - right
# Frame 184: Suggested action - right
# Frame 185: Suggested action - right
# Frame 186: Suggested action - right
# Frame 187: Suggested action - right
# Frame 188: Suggested action - right
# Frame 189: Suggested action - right
# Frame 190: Suggested action - right
# Frame 191: Suggested action - right
# Frame 192: Suggested action - right
# Frame 193: Suggested action - right
# Frame 194: Suggested action - right
# Frame 195: Suggested action - right
# Frame 196: Suggested action - right
# Frame 197: Suggested action - right
# Frame 198: Suggested action - right
# Frame 199: Suggested action - right
# Frame 200: Suggested action - right
# Frame 201: Suggested action - right
# Frame 202: Suggested action - right
# Frame 203: Suggested action - right
# Frame 204: Suggested action - right
# Frame 205: Suggested action - right
# Frame 206: Suggested action - right
# Frame 207: Suggested action - right
# Frame 208: Suggested action - right
# Frame 209: Suggested action - right
# Frame 210: Suggested action - right
# Frame 211: Suggested action - right
# Frame 212: Suggested action - right
# Frame 213: Suggested action - right
# Frame 214: Suggested action - right
# Frame 215: Suggested action - right
# Frame 216: Suggested action - right
# Frame 217: Suggested action - right
# Frame 218: Suggested action - right
# Frame 219: Suggested action - right
# Frame 220: Suggested action - right
# Frame 221: Suggested action - right
# Frame 222: Suggested action - right
# Frame 223: Suggested action - right
# Frame 224: Suggested action - right
# Frame 225: Suggested action - right
# Frame 226: Suggested action - right
# Frame 227: Suggested action - right
# Frame 228: Suggested action - right
# Frame 229: Suggested action - right
# Frame 230: Suggested action - right
# Frame 231: Suggested action - right
# Frame 232: Suggested action - right
# Frame 233: Suggested action - right
# Frame 234: Suggested action - right
# Frame 235: Suggested action - right
# Frame 236: Suggested action - right
# Frame 237: Suggested action - right
# Frame 238: Suggested action - right
# Frame 239: Suggested action - right
# Frame 240: Suggested action - right
# Frame 241: Suggested action - right
# Frame 242: Suggested action - right
# Frame 243: Suggested action - right
# Frame 244: Suggested action - right
# Frame 245: Suggested action - right
# Frame 246: Suggested action - right
# Frame 247: Suggested action - right
# Frame 248: Suggested action - right
# Frame 249: Suggested action - right
# Frame 250: Suggested action - right
# Frame 251: Suggested action - right
# Frame 252: Suggested action - right
# Frame 253: Suggested action - right
# Frame 254: Suggested action - right
# Frame 255: Suggested action - right
# Frame 256: Suggested action - right
# Frame 257: Suggested action - right
# Frame 258: Suggested action - right
# Frame 259: Suggested action - right
# Frame 260: Suggested action - right
# Frame 261: Suggested action - right
# Frame 262: Suggested action - right
# Frame 263: Suggested action - right
# Frame 264: Suggested action - right
# Frame 265: Suggested action - right
# Frame 266: Suggested action - right
# Frame 267: Suggested action - right
# Frame 268: Suggested action - right
# Frame 269: Suggested action - right
# Frame 270: Suggested action - right
# Frame 271: Suggested action - right
# Frame 272: Suggested action - right
# Frame 273: Suggested action - right
# Frame 274: Suggested action - right
# Frame 275: Suggested action - right
# Frame 276: Suggested action - right
# Frame 277: Suggested action - right
# Frame 278: Suggested action - right
# Frame 279: Suggested action - right
# Frame 280: Suggested action - right
# Frame 281: Suggested action - right
# Frame 282: Suggested action - right
# Frame 283: Suggested action - right
# Frame 284: Suggested action - right
# Frame 285: Suggested action - right
# Frame 286: Suggested action - right
# Frame 287: Suggested action - right
# Frame 288: Suggested action - right
# Frame 289: Suggested action - right
# Frame 290: Suggested action - right
# Frame 291: Suggested action - right
# Frame 292: Suggested action - right
# Frame 293: Suggested action - right
# Frame 294: Suggested action - right
# Frame 295: Suggested action - right
# Frame 296: Suggested action - right
# Frame 297: Suggested action - right
# Frame 298: Suggested action - right
# Frame 299: Suggested action - right
# Frame 300: Suggested action - right
# Frame 301: Suggested action - right
# Frame 302: Suggested action - right
# Frame 303: Suggested action - right
# Frame 304: Suggested action - right
# Frame 305: Suggested action - right
# Frame 306: Suggested action - right
# Frame 307: Suggested action - right
# Frame 308: Suggested action - right
# Frame 309: Suggested action - right
# Frame 310: Suggested action - right
# Frame 311: Suggested action - right
# Frame 312: Suggested action - right
# Frame 313: Suggested action - right
# Frame 314: Suggested action - right
# Frame 315: Suggested action - right
# Frame 316: Suggested action - right
# Frame 317: Suggested action - right
# Frame 318: Suggested action - right
# Frame 319: Suggested action - right
# Frame 320: Suggested action - right
# Frame 321: Suggested action - right
# Frame 322: Suggested action - right
# Frame 323: Suggested action - right
# Frame 324: Suggested action - right
# Frame 325: Suggested action - right
# Frame 326: Suggested action - right
# Frame 327: Suggested action - right
# Frame 328: Suggested action - right
# Frame 329: Suggested action - right
# Frame 330: Suggested action - right
# Frame 331: Suggested action - right
# Frame 332: Suggested action - right
# Frame 333: Suggested action - right
# Frame 334: Suggested action - right
# Frame 335: Suggested action - right
# Frame 336: Suggested action - right
# Frame 337: Suggested action - right
# Frame 338: Suggested action - right
# Frame 339: Suggested action - right
# Frame 340: Suggested action - right
# Frame 341: Suggested action - right
# Frame 342: Suggested action - right
# Frame 343: Suggested action - right
# Frame 344: Suggested action - right
# Frame 345: Suggested action - right
# Frame 346: Suggested action - right
# Frame 347: Suggested action - right
# Frame 348: Suggested action - right
# Frame 349: Suggested action - right
# Frame 350: Suggested action - right
# Frame 351: Suggested action - right
# Frame 352: Suggested action - right
# Frame 353: Suggested action - right
# Frame 354: Suggested action - right
# Frame 355: Suggested action - right
# Frame 356: Suggested action - right
# Frame 357: Suggested action - right
# Frame 358: Suggested action - right
# Frame 359: Suggested action - right
# Frame 360: Suggested action - right
# Frame 361: Suggested action - right
# Frame 362: Suggested action - right
# Frame 363: Suggested action - right
# Frame 364: Suggested action - right
# Frame 365: Suggested action - right
# Frame 366: Suggested action - right
# Frame 367: Suggested action - right
# Frame 368: Suggested action - right
# Frame 369: Suggested action - right
# Frame 370: Suggested action - right
# Frame 371: Suggested action - right
# Frame 372: Suggested action - right
# Frame 373: Suggested action - right
# Frame 374: Suggested action - right
# Frame 375: Suggested action - right
# Frame 376: Suggested action - right
# Frame 377: Suggested action - right
# Frame 378: Suggested action - right
# Frame 379: Suggested action - right
# Frame 380: Suggested action - right
# Frame 381: Suggested action - right
# Frame 382: Suggested action - right
# Frame 383: Suggested action - right
# Frame 384: Suggested action - right
# Frame 385: Suggested action - right
# Frame 386: Suggested action - right
# Frame 387: Suggested action - right
# Frame 388: Suggested action - right
# Frame 389: Suggested action - right
# Frame 390: Suggested action - right
# Frame 391: Suggested action - right
# Frame 392: Suggested action - right
# Frame 393: Suggested action - right
# Frame 394: Suggested action - right
# Frame 395: Suggested action - right
# Frame 396: Suggested action - right
# Frame 397: Suggested action - right
# Frame 398: Suggested action - right
# Frame 399: Suggested action - right
# Frame 400: Suggested action - right
# Frame 401: Suggested action - right
# Frame 402: Suggested action - right
# Frame 403: Suggested action - right
# Frame 404: Suggested action - right
# Frame 405: Suggested action - right
# Frame 406: Suggested action - right
# Frame 407: Suggested action - right
# Frame 408: Suggested action - right
# Frame 409: Suggested action - right
# Frame 410: Suggested action - right
# Frame 411: Suggested action - right
# Frame 412: Suggested action - right
# Frame 413: Suggested action - right
# Frame 414: Suggested action - right
# Frame 415: Suggested action - right
# Frame 416: Suggested action - right
# Frame 417: Suggested action - right
# Frame 418: Suggested action - right
# Frame 419: Suggested action - right
# Frame 420: Suggested action - right
# Frame 421: Suggested action - right
# Frame 422: Suggested action - right
# Frame 423: Suggested action - right
# Frame 424: Suggested action - center
# Frame 425: Suggested action - center
# Frame 426: Suggested action - center
# Frame 427: Suggested action - right
# Frame 428: Suggested action - center
# Frame 429: Suggested action - center
# Frame 430: Suggested action - center
# Frame 431: Suggested action - center
# Frame 432: Suggested action - center
# Frame 433: Suggested action - center
# Frame 434: Suggested action - center
# Frame 435: Suggested action - center
# Frame 436: Suggested action - center
# Frame 437: Suggested action - center
# Frame 438: Suggested action - center
# Frame 439: Suggested action - center
# Frame 440: Suggested action - center
# Frame 441: Suggested action - center
# Frame 442: Suggested action - center
# Frame 443: Suggested action - center
# Frame 444: Suggested action - center
# Frame 445: Suggested action - center
# Frame 446: Suggested action - center
# Frame 447: Suggested action - center
# Frame 448: Suggested action - center
# Frame 449: Suggested action - center
# Frame 450: Suggested action - center
# Frame 451: Suggested action - center
# Frame 452: Suggested action - center
# Frame 453: Suggested action - center
# Frame 454: Suggested action - center
# Frame 455: Suggested action - center
# Frame 456: Suggested action - center
# Frame 457: Suggested action - center
# Frame 458: Suggested action - center
# Frame 459: Suggested action - center
# Frame 460: Suggested action - center
# Frame 461: Suggested action - center
# Frame 462: Suggested action - center
# Frame 463: Suggested action - center
# Frame 464: Suggested action - center
# Frame 465: Suggested action - center
# Frame 466: Suggested action - center
# Frame 467: Suggested action - center
# Frame 468: Suggested action - center
# Frame 469: Suggested action - center
# Frame 470: Suggested action - center
# Frame 471: Suggested action - center
# Frame 472: Suggested action - center
# Frame 473: Suggested action - right
# Frame 474: Suggested action - center
# Frame 475: Suggested action - right
# Frame 476: Suggested action - center
# Frame 477: Suggested action - center
# Frame 478: Suggested action - center
# Frame 479: Suggested action - center
# Frame 480: Suggested action - center
# Frame 481: Suggested action - center
# Frame 482: Suggested action - center
# Frame 483: Suggested action - center
# Frame 484: Suggested action - center
# Frame 485: Suggested action - center
# Frame 486: Suggested action - center
# Frame 487: Suggested action - center
# Frame 488: Suggested action - center
# Frame 489: Suggested action - center
# Frame 490: Suggested action - center
# Frame 491: Suggested action - center
# Frame 492: Suggested action - center
# Frame 493: Suggested action - center
# Frame 494: Suggested action - center
# Frame 495: Suggested action - center
# Frame 496: Suggested action - center
# Frame 497: Suggested action - center
# Frame 498: Suggested action - center
# Frame 499: Suggested action - center
# Frame 500: Suggested action - center
# Frame 501: Suggested action - center
# Frame 502: Suggested action - center
# Frame 503: Suggested action - center
# Frame 504: Suggested action - center
# Frame 505: Suggested action - center
# Frame 506: Suggested action - center
# Frame 507: Suggested action - center
# Frame 508: Suggested action - center
# Frame 509: Suggested action - center
# Frame 510: Suggested action - center
# Frame 511: Suggested action - center
# Frame 512: Suggested action - center
# Frame 513: Suggested action - center
# Frame 514: Suggested action - center
# Frame 515: Suggested action - right
# Frame 516: Suggested action - center
# Frame 517: Suggested action - center
# Frame 518: Suggested action - center
# Frame 519: Suggested action - center
# Frame 520: Suggested action - center
# Frame 521: Suggested action - center
# Frame 522: Suggested action - right
# Frame 523: Suggested action - right
# Frame 524: Suggested action - right
# Frame 525: Suggested action - right
# Frame 526: Suggested action - right
# Frame 527: Suggested action - right
# Frame 528: Suggested action - right
# Frame 529: Suggested action - right
# Frame 530: Suggested action - center
# Frame 531: Suggested action - center
# Frame 532: Suggested action - right
# Frame 533: Suggested action - right
# Frame 534: Suggested action - right
# Frame 535: Suggested action - right
# Frame 536: Suggested action - right
# Frame 537: Suggested action - right
# Frame 538: Suggested action - right
# Frame 539: Suggested action - right
# Frame 540: Suggested action - right
# Frame 541: Suggested action - right
# Frame 542: Suggested action - right
# Frame 543: Suggested action - right
# Frame 544: Suggested action - right
# Frame 545: Suggested action - right
# Frame 546: Suggested action - right
# Frame 547: Suggested action - right
# Frame 548: Suggested action - right
# Frame 549: Suggested action - right
# Frame 550: Suggested action - right
# Frame 551: Suggested action - right
# Frame 552: Suggested action - right
# Frame 553: Suggested action - right
# Frame 554: Suggested action - right
# Frame 555: Suggested action - right
# Frame 556: Suggested action - right
# Frame 557: Suggested action - right
# Frame 558: Suggested action - right
# Frame 559: Suggested action - right
# Frame 560: Suggested action - right
# Frame 561: Suggested action - right
# Frame 562: Suggested action - right
# Frame 563: Suggested action - right
# Frame 564: Suggested action - right
# Frame 565: Suggested action - right
# Frame 566: Suggested action - right
# Frame 567: Suggested action - right
# Frame 568: Suggested action - right
# Frame 569: Suggested action - right
# Frame 570: Suggested action - right
# Frame 571: Suggested action - right
# Frame 572: Suggested action - right
# Frame 573: Suggested action - right
# Frame 574: Suggested action - right
# Frame 575: Suggested action - right
# Frame 576: Suggested action - right
# Frame 577: Suggested action - right
# Frame 578: Suggested action - right
# Frame 579: Suggested action - right
# Frame 580: Suggested action - right
# Frame 581: Suggested action - right
# Frame 582: Suggested action - right
# Frame 583: Suggested action - right
# Frame 584: Suggested action - right
# Frame 585: Suggested action - right
# Frame 586: Suggested action - right
# Frame 587: Suggested action - right
# Frame 588: Suggested action - right
# Frame 589: Suggested action - right
# Frame 590: Suggested action - right
# Frame 591: Suggested action - right
# Frame 592: Suggested action - right
# Frame 593: Suggested action - right
# Frame 594: Suggested action - right
# Frame 595: Suggested action - right
# Frame 596: Suggested action - right
# Frame 597: Suggested action - right
# Frame 598: Suggested action - right
# Frame 599: Suggested action - right
# Frame 600: Suggested action - right
# Frame 601: Suggested action - right
# Frame 602: Suggested action - right
# Frame 603: Suggested action - right
# Frame 604: Suggested action - right
# Frame 605: Suggested action - right
# Frame 606: Suggested action - right
# Frame 607: Suggested action - right
# Frame 608: Suggested action - right
# Frame 609: Suggested action - right
# Frame 610: Suggested action - right
# Frame 611: Suggested action - right
# Frame 612: Suggested action - right
# Frame 613: Suggested action - right
# Frame 614: Suggested action - right
# Frame 615: Suggested action - right
# Frame 616: Suggested action - right
# Frame 617: Suggested action - right
# Frame 618: Suggested action - center
# Frame 619: Suggested action - right
# Frame 620: Suggested action - center
# Frame 621: Suggested action - center
# Frame 622: Suggested action - center
# Frame 623: Suggested action - right
# Frame 624: Suggested action - right
# Frame 625: Suggested action - right
# Frame 626: Suggested action - right
# Frame 627: Suggested action - right
# Frame 628: Suggested action - right
# Frame 629: Suggested action - right
# Frame 630: Suggested action - right
# Frame 631: Suggested action - right
# Frame 632: Suggested action - right
# Frame 633: Suggested action - right
# Frame 634: Suggested action - center
# Frame 635: Suggested action - center
# Frame 636: Suggested action - center
# Frame 637: Suggested action - center
# Frame 638: Suggested action - center
# Frame 639: Suggested action - center
# Frame 640: Suggested action - center
# Frame 641: Suggested action - center
# Frame 642: Suggested action - center
# Frame 643: Suggested action - center
# Frame 644: Suggested action - center

# %%
import cv2
import numpy as np

def create_annotated_video(input_path, output_path, decision_interval=50):
    cap = cv2.VideoCapture(input_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    # Color settings
    colors = {
        'bg': (40, 40, 50),
        'text': (250, 250, 250),
        'left': (70, 120, 200),
        'center': (70, 180, 120),
        'right': (200, 120, 70)
    }

    current_frame = 0
    state = env.reset()
    current_decision = None
    decision_active = False

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Get YOLO detections
        results = model(frame)
        frame = results[0].plot()

        # Update decision every N frames
        if current_frame % decision_interval == 0:
            action = agent.get_action(state)
            current_decision = ['LEFT', 'CENTER', 'RIGHT'][action]
            decision_color = [colors['left'], colors['center'], colors['right']][action]
            decision_active = True

        # Display decision if active
        if decision_active:
            # Create header
            header = np.zeros((80, frame_width, 3), dtype=np.uint8)
            header[:] = colors['bg']

            # Add decision text
            cv2.putText(header, f"GOALKEEPER ACTION: {current_decision}",
                       (frame_width//2 - 200, 50),
                       cv2.FONT_HERSHEY_SIMPLEX, 1,
                       colors['text'], 2, cv2.LINE_AA)

            # Blend header
            frame[:80] = cv2.addWeighted(header, 0.8, frame[:80], 0.2, 0)

            # Add indicator bar at bottom
            cv2.rectangle(frame,
                         (0, frame_height-10),
                         (frame_width, frame_height),
                         decision_color, -1)

        # Add minimal frame counter
        cv2.putText(frame, f"{current_frame:04d}",
                   (frame_width - 100, 30),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7,
                   colors['text'], 1, cv2.LINE_AA)

        out.write(frame)

        if current_frame < len(detection_data) - 1:
            state, _, _, _ = env.step(action if 'action' in locals() else 0)
        current_frame += 1

    cap.release()
    out.release()
    print(f"Annotated video saved to {output_path}")

# Create the video
create_annotated_video('/content/istockphoto-949472108-640_adpp_is.mp4', 'output.mp4', decision_interval=50)
# Out:
# Annotated video saved to output.mp4

# %%
import pickle
import numpy as np

def save_agent(agent, filepath):
    """Save the Q-learning agent to a file"""
    with open(filepath, 'wb') as f:
        pickle.dump({
            'q_table': agent.q_table,
            'epsilon': agent.epsilon,
            'learning_rate': agent.lr,
            'discount_factor': agent.gamma,
            'exploration_decay': agent.epsilon_decay,
            'state_mapping': agent.discretize_state.__code__.co_code  # Save state processing logic
        }, f)

# Save the agent
save_agent(agent, '/content/drive/MyDrive/penalty_kick_agent.pkl')

# %%
# Export YOLO model to ONNX format (best for web deployment)
model.export(format='onnx', imgsz=[640, 640])  # Adjust image size as needed

# Move to Drive
# !cp yolov8n.onnx "/content/drive/MyDrive/yolov8_penalty_detector.onnx"
# Out:
# Ultralytics 8.3.104 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.49...
# ONNX: export success ✅ 1.7s, saved as 'yolov8n.onnx' (12.2 MB)
#
# Export complete (2.3s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolov8n.onnx imgsz=640
# Validate:        yolo val task=detect model=yolov8n.onnx imgsz=640 data=coco.yaml
# Visualize:       https://netron.app

# %%
env_config = {
    'frame_size': (1280, 720),  # Your video dimensions
    'action_meanings': ['left', 'center', 'right'],
    'observation_space': {
        'low': [0, 0, 0],
        'high': [1, 1, 1]
    }
}

import json
with open('/content/drive/MyDrive/env_config.json', 'w') as f:
    json.dump(env_config, f)

# %%
# Zip all necessary files
# !zip -r "/content/model_package.zip" \
    "/content/drive/MyDrive/penalty_kick_agent.pkl" \
    "/content/drive/MyDrive/yolov8_penalty_detector.onnx" \
    "/content/drive/MyDrive/env_config.json"

# Download the package
from google.colab import files
files.download("/content/model_package.zip")
# Out:
#   adding: content/drive/MyDrive/penalty_kick_agent.pkl (deflated 98%)
#   adding: content/drive/MyDrive/yolov8_penalty_detector.onnx (deflated 14%)
#   adding: content/drive/MyDrive/env_config.json (deflated 21%)
